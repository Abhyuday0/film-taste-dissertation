# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\abhyu\Desktop\Dissertation\Code\Data Testing\FINAL_movie_data_updated.csv")
data = data.drop('Unnamed: 0', axis=1)
# data[1]
data
# Out:
#                                   title    year  length  letterboxd_rating  \
# 0                                A Hero  2021.0   127.0               7.54
# 1                             Hailstone  2023.0     4.0                NaN
# 2                          Kaleidoscope     NaN     3.0                NaN
# 3                          You're Loved  2023.0    60.0                NaN
# 4       Love, Death & Robots: Zima Blue  2019.0    10.0               8.16
# ...                                 ...     ...     ...                ...
# 10180                    Pool of London  1951.0    85.0               7.12
# 10181      Guess Who's Coming to Dinner  1967.0   108.0               7.50
# 10182  Fear City: A Family-Style Comedy  1994.0    93.0               7.74
# 10183                   Fatal Deviation  1998.0    77.0               5.62
# 10184        The Umbrellas of Cherbourg  1964.0    91.0               8.16
#
#        letterboxd_views         director                country  \
# ...

# %%
data.to_csv(r"C:\Users\abhyu\Desktop\Dissertation\Code\Data Testing\FINAL_movie_data_updated.csv", index = False)
